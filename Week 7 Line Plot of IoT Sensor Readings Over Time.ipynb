# %%
pip install web3
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Connect to Ganache
w3 = Web3(Web3.HTTPProvider("http://127.0.0.1:8545"))

# Verify connection
if w3.is_connected():
    print("✅ Connected to Ganache successfully")
else:
    print("❌ Connection failed. Ensure Ganache is running.")
# Out:
# ✅ Connected to Ganache successfully

# %%
# Load ABI from file
with open(r"C:\Users\Chico\Desktop\LogisticsDataStorageABI.json") as f:
    abi = json.load(f)

# Contract address from your deployment
contract_address = "0xb38F89bae966804f64cD50e55dD7AC5982836619"
contract = w3.eth.contract(address=contract_address, abi=abi)

# Set default account (Ganache provides accounts automatically)
w3.eth.default_account = w3.eth.accounts[0]

print(f"✅ Connected to Smart Contract at {contract_address}")
print(f"Default sender account: {w3.eth.default_account}")
# Out:
# ✅ Connected to Smart Contract at 0xb38F89bae966804f64cD50e55dD7AC5982836619
# Default sender account: 0xB56C6D8729cb681d81Fe2dDFFcf4348a91a353b5

# %%
import json

from web3 import Web3

import pandas as pd





# Load IoT sensor data from CSV (Generated in Homework 1)

df = pd.read_csv("logistics_data.csv")





# Display the first few rows

print(df.head())
# Out:
#                     timestamp shipment_id    rfid_tag vehicle_id driver_id  \
# 0  2026-05-08 18:54:41.150840     SHP1436  RFID351619     VEH237     DRV48
# 1  2026-05-08 03:39:41.153257     SHP7361  RFID345028     VEH509     DRV10
# 2  2026-05-08 23:44:41.153257     SHP7013  RFID466093     VEH289     DRV54
# 3  2026-05-08 08:16:41.153257     SHP3388  RFID493413     VEH805     DRV53
# 4  2026-05-08 17:06:41.153257     SHP9429  RFID614526     VEH676     DRV97
#
#    origin destination  distance_km          scheduled_delivery  \
# 0  Manila      Iloilo        910.2  2026-05-11 09:54:41.152062
# 1  Iloilo      Iloilo        203.9  2026-05-09 13:54:41.153257
# 2   Clark       Davao        873.0  2026-05-10 05:54:41.153257
# 3   Clark       Davao        889.2  2026-05-10 13:54:41.153257
# 4  Iloilo       Clark        832.2  2026-05-12 01:54:41.153257
#
#               actual_delivery     status  cargo_weight_kg   cargo_type  \
# ...

# %%
from web3 import Web3


# Connect to local blockchain
ganache_url = "http://127.0.0.1:8545"
web3 = Web3(Web3.HTTPProvider(ganache_url))


# Verify connection
if web3.is_connected():
    print("✅ Connected to Ganache successfully!")
else:
    print("❌ Connection failed. Ensure Ganache is running.")
# Out:
# ✅ Connected to Ganache successfully!

# %%
# Replace with actual contract address from Remix
contract_address = "0xb38F89bae966804f64cD50e55dD7AC5982836619"


# Paste the ABI from Remix
abi = [
	{
		"anonymous": False,
		"inputs": [
			{
				"indexed": True,
				"internalType": "uint256",
				"name": "recordID",
				"type": "uint256"
			},
			{
				"indexed": False,
				"internalType": "string",
				"name": "shipmentID",
				"type": "string"
			},
			{
				"indexed": False,
				"internalType": "string",
				"name": "rfidTag",
				"type": "string"
			},
			{
				"indexed": False,
				"internalType": "string",
				"name": "vehicleID",
				"type": "string"
			},
			{
				"indexed": False,
				"internalType": "string",
				"name": "origin",
				"type": "string"
			},
			{
				"indexed": False,
				"internalType": "string",
				"name": "destination",
				"type": "string"
			},
			{
				"indexed": False,
				"internalType": "string",
				"name": "status",
				"type": "string"
			},
			{
				"indexed": False,
				"internalType": "string",
				"name": "cargoType",
				"type": "string"
			},
			{
				"indexed": False,
				"internalType": "string",
				"name": "temperature",
				"type": "string"
			},
			{
				"indexed": False,
				"internalType": "string",
				"name": "delayHours",
				"type": "string"
			},
			{
				"indexed": False,
				"internalType": "string",
				"name": "co2Emissions",
				"type": "string"
			},
			{
				"indexed": False,
				"internalType": "uint256",
				"name": "blockchainTimestamp",
				"type": "uint256"
			},
			{
				"indexed": False,
				"internalType": "address",
				"name": "recordedBy",
				"type": "address"
			}
		],
		"name": "ShipmentStored",
		"type": "event"
	},
	{
		"inputs": [
			{
				"internalType": "string",
				"name": "_shipmentID",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "_rfidTag",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "_vehicleID",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "_origin",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "_destination",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "_status",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "_cargoType",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "_temperature",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "_delayHours",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "_co2Emissions",
				"type": "string"
			}
		],
		"name": "storeShipmentData",
		"outputs": [],
		"stateMutability": "nonpayable",
		"type": "function"
	},
	{
		"inputs": [
			{
				"internalType": "uint256",
				"name": "_recordID",
				"type": "uint256"
			}
		],
		"name": "getShipmentData",
		"outputs": [
			{
				"internalType": "string",
				"name": "shipmentID",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "rfidTag",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "vehicleID",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "origin",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "destination",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "status",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "cargoType",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "temperature",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "delayHours",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "co2Emissions",
				"type": "string"
			},
			{
				"internalType": "uint256",
				"name": "blockchainTimestamp",
				"type": "uint256"
			},
			{
				"internalType": "address",
				"name": "recordedBy",
				"type": "address"
			}
		],
		"stateMutability": "view",
		"type": "function"
	},
	{
		"inputs": [],
		"name": "getTotalRecords",
		"outputs": [
			{
				"internalType": "uint256",
				"name": "",
				"type": "uint256"
			}
		],
		"stateMutability": "view",
		"type": "function"
	}
]  # Replace with your contract ABI


# Load the smart contract
contract = web3.eth.contract(address=contract_address, abi=abi)


# Set default sender (first account from Ganache)
web3.eth.default_account = web3.eth.accounts[0]


print(f"✅ Connected to Smart Contract at {contract_address}")
# Out:
# ✅ Connected to Smart Contract at 0xb38F89bae966804f64cD50e55dD7AC5982836619

# %%
import time

def send_shipment_core(shipment_id, rfid_tag, vehicle_id, origin, destination, status, cargo_type, temperature, delay_hours, co2_emissions):
    """Sends shipment data to the deployed smart contract matching the ABI specification"""
    
    # storeShipmentData expects exactly 10 string arguments
    txn = contract.functions.storeShipmentData(
        str(shipment_id),
        str(rfid_tag),
        str(vehicle_id),
        str(origin),
        str(destination),
        str(status),
        str(cargo_type),
        str(temperature_c),
        str(delay_hours),
        str(co2_emissions_kg)
    ).transact({
        'from': w3.eth.accounts[0],
        'gas': 3000000
    })
    
    receipt = w3.eth.wait_for_transaction_receipt(txn)
    print(f"✅ Shipment {shipment_id} stored, Txn Hash: {receipt.transactionHash.hex()}")
    
    # Optional delay if you are calling this in rapid succession to prevent flooding Ganache
    time.sleep(1)

# %%
for _, row in df.iterrows():
    # Make sure you are calling 'storeShipmentData' with the exact 10 arguments required
    txn = contract.functions.storeShipmentData(
        str(row["shipment_id"]),     # _shipmentID
        str(row["rfid_tag"]),        # _rfidTag
        str(row["vehicle_id"]),      # _vehicleID
        str(row["origin"]),          # _origin
        str(row["destination"]),     # _destination
        str(row["status"]),          # _status
        str(row["cargo_type"]),      # _cargoType
        str(row["temperature_c"]),     # _temperature
        str(row["delay_hours"]),     # _delayHours
        str(row["co2_emissions_kg"])    # _co2Emissions
    ).transact({
        'from': w3.eth.accounts[0],
        'gas': 1000000
    })
    
    txn_hash = w3.eth.wait_for_transaction_receipt(txn)
    print(f"✅ Shipment {row['shipment_id']} stored on blockchain!")
    time.sleep(1) # prevent flooding Ganache
# Out:
# ✅ Shipment SHP1436 stored on blockchain!
# ✅ Shipment SHP7361 stored on blockchain!
# ✅ Shipment SHP7013 stored on blockchain!
# ✅ Shipment SHP3388 stored on blockchain!
# ✅ Shipment SHP9429 stored on blockchain!
# ✅ Shipment SHP3815 stored on blockchain!
# ✅ Shipment SHP2881 stored on blockchain!
# ✅ Shipment SHP6130 stored on blockchain!
# ✅ Shipment SHP8117 stored on blockchain!
# ✅ Shipment SHP8954 stored on blockchain!
# ✅ Shipment SHP4392 stored on blockchain!
# ✅ Shipment SHP8301 stored on blockchain!
# ✅ Shipment SHP1262 stored on blockchain!
# ✅ Shipment SHP7674 stored on blockchain!
# ✅ Shipment SHP9819 stored on blockchain!
# ✅ Shipment SHP9656 stored on blockchain!
# ✅ Shipment SHP4906 stored on blockchain!
# ✅ Shipment SHP9730 stored on blockchain!
# ✅ Shipment SHP9515 stored on blockchain!
# ✅ Shipment SHP4441 stored on blockchain!
# ✅ Shipment SHP1652 stored on blockchain!
# ✅ Shipment SHP4972 stored on blockchain!
# ✅ Shipment SHP6782 stored on blockchain!
# ...

# %%
total_records = contract.functions.getTotalRecords().call()
print(f"Total IoT records stored: {total_records}")
# Out:
# Total IoT records stored: 101

# %%
# Use the correct function name defined in your ABI
record = contract.functions.getShipmentData(0).call()

print("First Stored Record:", record)
# Out:
# First Stored Record: ['SHIP001', 'RFID001', 'TRUCK001', 'Manila Warehouse', 'Cebu Distribution Center', 'In Transit', 'Electronics', '22.5°C', '0', '15.3 kg', 1780756066, '0xB56C6D8729cb681d81Fe2dDFFcf4348a91a353b5']

# %%
total_records = contract.functions.getTotalRecords().call()
print(f"Total IoT records stored: {total_records}")
# Out:
# Total IoT records stored: 101

# %%
import pandas as pd

# Retrieve all IoT records
data = []
total_records = contract.functions.getTotalRecords().call()

for i in range(total_records):
    # Call the correct function from your ABI
    record = contract.functions.getShipmentData(i).call()
    
    # record is a tuple mapping directly to the 12 ABI function outputs
    data.append({
        "shipment_id": record[0],
        "rfid_tag": record[1],
        "vehicle_id": record[2],
        "origin": record[3],
        "destination": record[4],
        "status": record[5],
        "cargo_type": record[6],
        "temperature": record[7],
        "delay_hours": record[8],
        "co2_emissions": record[9],
        "timestamp": record[10],     # blockchainTimestamp is index 10
        "recorded_by": record[11]     # recordedBy address is index 11
    })

# Convert to a DataFrame
df = pd.DataFrame(data)

# Convert blockchainTimestamp to a readable format
# (Only do this if total_records > 0 to prevent pandas errors on empty data)
if not df.empty:
    df["timestamp"] = pd.to_datetime(df["timestamp"], unit="s")

# Display first few records
print(df.head())
# Out:
#   shipment_id    rfid_tag vehicle_id            origin  \
# 0     SHIP001     RFID001   TRUCK001  Manila Warehouse
# 1     SHP1436  RFID351619     VEH237            Manila
# 2     SHP7361  RFID345028     VEH509            Iloilo
# 3     SHP7013  RFID466093     VEH289             Clark
# 4     SHP3388  RFID493413     VEH805             Clark
#
#                 destination      status   cargo_type temperature delay_hours  \
# 0  Cebu Distribution Center  In Transit  Electronics      22.5°C           0
# 1                    Iloilo   Cancelled     Clothing        20.8       -50.0
# 2                    Iloilo   Delivered     Clothing        30.4        47.0
# 3                     Davao   Delivered     Clothing        19.7       -24.0
# 4                     Davao     Delayed     Clothing        20.2         1.0
#
#   co2_emissions           timestamp  \
# 0       15.3 kg 2026-06-06 14:27:46
# 1        142.64 2026-06-06 15:23:52
# 2        129.31 2026-06-06 15:23:53
# ...

# %%
import numpy as np

# 1. Clean and extract numeric values from the specific string columns
df["temperature"] = df["temperature"].str.extract(r'(-?\d+\.?\d*)').astype(float)
df["delay_hours"] = df["delay_hours"].str.extract(r'(\d+\.?\d*)').astype(float)
df["co2_emissions"] = df["co2_emissions"].str.extract(r'(\d+\.?\d*)').astype(float)

# 2. Handle missing values (fills NaN values resulting from empty strings or failed extractions)
df.fillna({
    "temperature": 0.0,
    "delay_hours": 0.0,
    "co2_emissions": 0.0,
    "status": "Unknown"
}, inplace=True)

# Display cleaned data showing your specific logistics features
print(df[["shipment_id", "status", "temperature", "delay_hours", "co2_emissions"]].head())
# Out:
#   shipment_id      status  temperature  delay_hours  co2_emissions
# 0     SHIP001  In Transit         22.5          0.0          15.30
# 1     SHP1436   Cancelled         20.8         50.0         142.64
# 2     SHP7361   Delivered         30.4         47.0         129.31
# 3     SHP7013   Delivered         19.7         24.0          61.10
# 4     SHP3388     Delayed         20.2          1.0         391.87

# %%
# Save cleaned IoT data to a CSV file
df.to_csv("cleaned_iot_data.csv", index=False)


print("✅ Cleaned IoT data saved successfully as cleaned_iot_data.csv")
# Out:
# ✅ Cleaned IoT data saved successfully as cleaned_iot_data.csv

# %%
import pandas as pd


# Load cleaned IoT data
df = pd.read_csv("cleaned_iot_data.csv")


# Display first few rows to verify data
print(df.head())
# Out:
#   shipment_id    rfid_tag vehicle_id            origin  \
# 0     SHIP001     RFID001   TRUCK001  Manila Warehouse
# 1     SHP1436  RFID351619     VEH237            Manila
# 2     SHP7361  RFID345028     VEH509            Iloilo
# 3     SHP7013  RFID466093     VEH289             Clark
# 4     SHP3388  RFID493413     VEH805             Clark
#
#                 destination      status   cargo_type  temperature  \
# 0  Cebu Distribution Center  In Transit  Electronics         22.5
# 1                    Iloilo   Cancelled     Clothing         20.8
# 2                    Iloilo   Delivered     Clothing         30.4
# 3                     Davao   Delivered     Clothing         19.7
# 4                     Davao     Delayed     Clothing         20.2
#
#    delay_hours  co2_emissions            timestamp  \
# 0          0.0          15.30  2026-06-06 14:27:46
# 1         50.0         142.64  2026-06-06 15:23:52
# 2         47.0         129.31  2026-06-06 15:23:53
# ...

# %%
# Convert timestamp column to datetime
df["timestamp"] = pd.to_datetime(df["timestamp"])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set(style="whitegrid")

# %%
plt.figure(figsize=(12, 6))


sns.lineplot(
    data=df,
    x="timestamp", 
    y="temperature",     # <-- Changed from 'numeric_value' to 'temperature'
    hue="cargo_type",    # <-- Changed from 'data_type' to 'cargo_type' (or use 'status'/'recorded_by')
    marker="o"
)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Add title and labels
plt.title("IoT Sensor Readings Over Time", fontsize=14)
plt.xlabel("Timestamp", fontsize=12)
plt.ylabel("Sensor Value (Temperature)", fontsize=12)

# Show Legend
plt.legend(title="Cargo Type")

plt.show()
